# %%
import mpld3
from mpld3 import enable_notebook
#enable_notebook()
import pygal as gal

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import PerceptonSetup as P

# %% [markdown]
# ## Creating the random line

# %%
new_line = P.random_line()
domain = np.linspace(-1, 11)
plt.plot(domain, new_line(domain))
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.style.use('ggplot')
plt.show()
# Out:
# (-1, 1)
# (-1, 1)

# %%
 plt.style.available
# Out:
# ['seaborn-talk',
#  'grayscale',
#  'bmh',
#  'seaborn-pastel',
#  'seaborn-white',
#  'seaborn-dark',
#  'seaborn-paper',
#  'dark_background',
#  'seaborn-whitegrid',
#  'seaborn-muted',
#  'seaborn-deep',
#  'fivethirtyeight',
#  'seaborn-notebook',
#  'seaborn-darkgrid',
#  'seaborn-dark-palette',
#  'seaborn-ticks',
#  'seaborn-bright',
#  'classic',
#  'seaborn-colorblind',
#  'seaborn',
#  'seaborn-poster',
#  'ggplot']

# %%
xy_object=gal.XY(xrange=(-1,1),range=(-1,1))
xy_object.add('new line',[(x,new_line(x)) for x in domain])
xy_object.render()
# Out:
# b'<?xml version=\'1.0\' encoding=\'utf-8\'?>\n<svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-789a0c29-d259-4147-8020-2aff17361af5" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 2.4.0 (lxml) \xc2\xa9Kozea 2012-2016 on 2017-09-21--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-789a0c29-d259-4147-8020-2aff17361af5{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-789a0c29-d259-4147-8020-2aff17361af5 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-789a0c29-d259-4147-8020-2aff17361af5 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-789a0c29-d259-4147-8020-2aff17361af5 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-789a0c29-d259-4147-8020-2aff17361af5 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-789a0c29-d259-4147-8020-2aff17361af5 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-789a0c29-d259-4147-8020-2aff17361af5 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-789a0c29-d259-4147-8020-2aff17361af5 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-789a0c29-d259-4147-8020-2aff17361af5 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}\n#chart-789a0c29-d259-4147-8020-2aff17361af5{background-color:rgba(249,249,249,1)}#chart-789a0c29-d259-4147-8020-2aff17361af5 path,#chart-789a0c29-d259-4147-8020-2aff17361af5 line,#chart-789a0c29-d259-4147-8020-2aff17361af5 rect,#chart-789a0c29-d259-4147-8020-2aff17361af5 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-789a0c29-d259-4147-8020-2aff17361af5 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-789a0c29-d259-4147-8020-2aff17361af5 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-789a0c29-d259-4147-8020-2aff17361af5 .graph{fill:rgba(0,0,0,.87)}#chart-789a0c29-d259-4147-8020-2aff17361af5 text.no_data{fill:rgba(0,0,0,1)}#chart-789a0c29-d259-4147-8020-2aff17361af5 .title{fill:rgba(0,0,0,1)}#chart-789a0c29-d259-4147-8020-2aff17361af5 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-789a0c29-d259-4147-8020-2aff17361af5 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-789a0c29-d259-4147-8020-2aff17361af5 .axis .line{stroke:rgba(0,0,0,1)}#chart-789a0c29-d259-4147-8020-2aff17361af5 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-789a0c29-d259-4147-8020-2aff17361af5 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-789a0c29-d259-4147-8020-2aff17361af5 .axis text.major{fill:rgba(0,0,0,1)}#chart-789a0c29-d259-4147-8020-2aff17361af5 .axis.y .guides:hover .guide.line,#chart-789a0c29-d259-4147-8020-2aff17361af5 .line-graph .axis.x .guides:hover .guide.line,#chart-789a0c29-d259-4147-8020-2aff17361af5 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-789a0c29-d259-4147-8020-2aff17361af5 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-789a0c29-d259-4147-8020-2aff17361af5 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-789a0c29-d259-4147-8020-2aff17361af5 .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-789a0c29-d259-4147-8020-2aff17361af5 .ci{stroke:rgba(0,0,0,.87)}#chart-789a0c29-d259-4147-8020-2aff17361af5 .reactive.active,#chart-789a0c29-d259-4147-8020-2aff17361af5 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-789a0c29-d259-4147-8020-2aff17361af5 .ci .reactive.active{stroke-width:1.5}#chart-789a0c29-d259-4147-8020-2aff17361af5 .series text{fill:rgba(0,0,0,1)}#chart-789a0c29-d259-4147-8020-2aff17361af5 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-m ...
# <b>limit_output extension: Maximum message size of 10000 exceeded with 30080 characters</b>

# %%
P.classifier(0, 0, new_line)
# Out:
# -1

# %%
b = new_line(0)
m = new_line(1) - b
print(b,m)
# Out:
# 0.5357570983578535 0.31530700594619343

# %% [markdown]
# ## Creating the random points

# %%
x_list, y_list = P.random_points(100)

# %%
type(x_list)
# Out:
# list

# %%
output_list = P.point_assigner(x_list, y_list, new_line)

# %% [markdown]
# ## Storing the nesscary parts

# %%
import pickle
with open("mypickle.pickle", "wb") as f:
    pickle.dump([b,m,x_list,y_list,output_list], f)

# %%
X=np.random.normal(0,1,(100,3))
color=np.random.random(100)
size=500*np.random.random(100)
plt.scatter(X[:,0],X[:,1],c=color,s=size,alpha=0.5,linewidth=2)
plt.grid(color='lightgray',alpha=0.7)

# %%
mpld3.display(plt.scatter)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-a5d6431387a1> in <module>()
# ----> 1 mpld3.display(plt.scatter)
#
# /home/benson/Software/anaconda3/lib/python3.6/site-packages/mpld3/_display.py in display(fig, closefig, local, **kwargs)
#     302         fig = plt.gcf()
#     303     if closefig:
# --> 304         plt.close(fig)
#     305     return HTML(fig_to_html(fig, **kwargs))
#     306
#
# /home/benson/Software/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in close(*args)
#     662             _pylab_helpers.Gcf.destroy_fig(arg)
#     663         else:
# --> 664             raise TypeError('Unrecognized argument type %s to close' % type(arg))
#     665     else:
#     666         raise TypeError('close takes 0 or 1 arguments')
#
# TypeError: Unrecognized argument type <class 'function'> to close
